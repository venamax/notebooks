# %%
import pandas as pd

# %% [markdown]
# # Data Ingestion

# %% [markdown]
# s3://dataincubator-course/mldata/train.txt.gz

# %%
# !wget https://s3.amazonaws.com/thedataincubator-course/mldata/train.txt.gz
# Out:
# --2016-04-21 14:42:09--  https://s3.amazonaws.com/thedataincubator-course/mldata/train.txt.gz
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 54.231.15.8
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|54.231.15.8|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5503948 (5.2M) [text/plain]
# Saving to: ‘train.txt.gz’
#
# 100%[======================================>] 5,503,948   15.8MB/s   in 0.3s
#
# 2016-04-21 14:42:10 (15.8 MB/s) - ‘train.txt.gz’ saved [5503948/5503948]

# %%
# !ls
# Out:
# README.md  train.txt  TS.ipynb

# %%
# !gunzip train.txt.gz

# %%
# !ls
# Out:
# README.md  train.txt  TS.ipynb

# %%
df = pd.read_csv("train.txt", header=None, delim_whitespace=True)

# %%
df.columns = ['year', 'month', 'day', 'hour', 'temp', 'dew_temp', 'pressure','wind_angle', 'wind_speed', 'sky_code', 'rain_hour', 'rain_6hour',
  'city']

# %%
df
# Out:
#         year  month  day  hour  temp  dew_temp  pressure  wind_angle  \
# 0       2000      1    1     0   -11       -72     10197         220
# 1       2000      1    1     1    -6       -78     10206         230
# 2       2000      1    1     2   -17       -78     10211         230
# 3       2000      1    1     3   -17       -78     10214         230
# 4       2000      1    1     4   -17       -78     10216         230
# 5       2000      1    1     5   -22       -78     10218         230
# 6       2000      1    1     6   -28       -83     10219         230
# 7       2000      1    1     7     0       -78     10222         280
# 8       2000      1    1     8   -11       -72     10231         240
# 9       2000      1    1     9   -28       -78     10228         230
# 10      2000      1    1    10   -28       -72     10230         240
# 11      2000      1    1    11   -22       -72     10235         230
# 12      2000      1    1    12   -22       -67     10244         240
# ...
